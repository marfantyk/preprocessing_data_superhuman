# %% [markdown]
# # Superhuman genes data filtering notebook

# %% [markdown]
# The purpose of this notebook to parse data provided by curator

# %%
import polars as pl
from pathlib import *
import sqlite3

# %% [markdown]
# ### Setting up paths

# %%
base = Path(".")
data = base / "data"
input = data / "input"
output = data / "output"

# %%
superhuman_path = input / "superhuman.tsv"
superhuman_db = pl.read_csv(str(superhuman_path), sep='\t')
superhuman_db.head()
# Out:
# shape: (5, 11)
# ┌────────────┬──────┬────────────┬───────────┬─────┬──────────┬────────────┬────────────┬──────────┐
# │ rsID       ┆ Gene ┆ Polymorphi ┆ Location  ┆ ... ┆ Zygosity ┆ Superabili ┆ Adverse    ┆ Referenc │
# │ ---        ┆ ---  ┆ sm         ┆ 38        ┆     ┆ ---      ┆ ty         ┆ effects    ┆ es       │
# │ str        ┆ str  ┆ ---        ┆ ---       ┆     ┆ str      ┆ ---        ┆ ---        ┆ ---      │
# │            ┆      ┆ str        ┆ str       ┆     ┆          ┆ str        ┆ str        ┆ str      │
# ╞════════════╪══════╪════════════╪═══════════╪═════╪══════════╪════════════╪════════════╪══════════╡
# │ rs12190866 ┆ LRP5 ┆ G171V/+    ┆ 11:683576 ┆ ... ┆ null     ┆ Extra      ┆ Osteoscler ┆ https:// │
# │ 8          ┆      ┆            ┆ 73        ┆     ┆          ┆ strong     ┆ osis       ┆ pubmed.n │
# │            ┆      ┆            ┆           ┆     ┆          ┆ bones;     ┆ (ref); Low ┆ cbi.nlm. │
# │            ┆      ┆            ┆           ┆     ┆          ┆ increased  ┆ Buoyan...  ┆ nih.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ bo...      ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs12105165 ┆ MSTN ┆ -/-        ┆ 2:1900557 ┆ ... ┆ null     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 44        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs37425613 ┆ MSTN ┆ -/-        ┆ 2:1900576 ┆ ... ┆ null     ┆ Large,     ┆ Not        ┆ https:// │
# │ 6          ┆      ┆            ┆ 41        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs3187415  ┆ MSTN ┆ -/-        ┆ 2:1900560 ┆ ... ┆ null     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 55        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs1805085  ┆ MSTN ┆ -/-        ┆ 2:1900624 ┆ ... ┆ null     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 34        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# └────────────┴──────┴────────────┴───────────┴─────┴──────────┴────────────┴────────────┴──────────┘

# %% [markdown]
# Dividing column for Alt allele into separate rows

# %%
superhuman = (
    superhuman_db
    .with_columns(
        [
            (pl.col("Alt allele").str.replace(' ', '')
                            .str.split(',')),
            (pl.col("Zygosity").fill_null('both'))
        ]
    )
    .pipe(
        lambda df:df.rename({oldCol:oldCol.lower().replace(' ','_') for oldCol in df.columns})
    )
)

superhuman.head()
# Out:
# shape: (5, 11)
# ┌────────────┬──────┬────────────┬───────────┬─────┬──────────┬────────────┬────────────┬──────────┐
# │ rsid       ┆ gene ┆ polymorphi ┆ location_ ┆ ... ┆ zygosity ┆ superabili ┆ adverse_ef ┆ referenc │
# │ ---        ┆ ---  ┆ sm         ┆ 38        ┆     ┆ ---      ┆ ty         ┆ fects      ┆ es       │
# │ str        ┆ str  ┆ ---        ┆ ---       ┆     ┆ str      ┆ ---        ┆ ---        ┆ ---      │
# │            ┆      ┆ str        ┆ str       ┆     ┆          ┆ str        ┆ str        ┆ str      │
# ╞════════════╪══════╪════════════╪═══════════╪═════╪══════════╪════════════╪════════════╪══════════╡
# │ rs12190866 ┆ LRP5 ┆ G171V/+    ┆ 11:683576 ┆ ... ┆ both     ┆ Extra      ┆ Osteoscler ┆ https:// │
# │ 8          ┆      ┆            ┆ 73        ┆     ┆          ┆ strong     ┆ osis       ┆ pubmed.n │
# │            ┆      ┆            ┆           ┆     ┆          ┆ bones;     ┆ (ref); Low ┆ cbi.nlm. │
# │            ┆      ┆            ┆           ┆     ┆          ┆ increased  ┆ Buoyan...  ┆ nih.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ bo...      ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs12105165 ┆ MSTN ┆ -/-        ┆ 2:1900557 ┆ ... ┆ both     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 44        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs37425613 ┆ MSTN ┆ -/-        ┆ 2:1900576 ┆ ... ┆ both     ┆ Large,     ┆ Not        ┆ https:// │
# │ 6          ┆      ┆            ┆ 41        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs3187415  ┆ MSTN ┆ -/-        ┆ 2:1900560 ┆ ... ┆ both     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 55        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ rs1805085  ┆ MSTN ┆ -/-        ┆ 2:1900624 ┆ ... ┆ both     ┆ Large,     ┆ Not        ┆ https:// │
# │            ┆      ┆            ┆ 34        ┆     ┆          ┆ lean       ┆ reported   ┆ medlinep │
# │            ┆      ┆            ┆           ┆     ┆          ┆ muscles,   ┆            ┆ lus.gov/ │
# │            ┆      ┆            ┆           ┆     ┆          ┆ low        ┆            ┆ genetics │
# │            ┆      ┆            ┆           ┆     ┆          ┆ atheros... ┆            ┆ ...      │
# └────────────┴──────┴────────────┴───────────┴─────┴──────────┴────────────┴────────────┴──────────┘

# %% [markdown]
# Preparing names of columns for sqlite db

# %%
superhuman_pandas = superhuman.explode('alt_allele').to_pandas()

# %% [markdown]
# Clearing output

# %%
import shutil
if output.exists():
    shutil.rmtree(output)
output.mkdir()

# %% [markdown]
# Creating sqlite database

# %%
sqlite_db_path = output / 'superhuman.sqlite'

sqlite_con = sqlite3.connect(sqlite_db_path)
(
    superhuman_pandas
    .sort_values("rsid")
    .to_sql('superhuman', sqlite_con, if_exists='replace', index=False)
)
# Out:
# 1243

# %%
sqlite_con.close()
